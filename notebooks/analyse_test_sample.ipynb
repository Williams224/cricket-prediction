# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/TimothyW/Fun/cricket_prediction/test_sample.csv")

# %%
df
# Out:
#         Unnamed: 0  over_n           batter    bowler      non_striker  \
# 0                0       0          M Vijay  KD Mills        G Gambhir
# 1                1       0          M Vijay  KD Mills        G Gambhir
# 2                2       0          M Vijay  KD Mills        G Gambhir
# 3                3       0          M Vijay  KD Mills        G Gambhir
# 4                4       0        G Gambhir  KD Mills          M Vijay
# ...            ...     ...              ...       ...              ...
# 109623         164      26    JDF Vandersay  IS Sodhi  KMDN Kulasekara
# 109624         165      27  KMDN Kulasekara  MJ Henry    JDF Vandersay
# 109625         166      27  KMDN Kulasekara  MJ Henry    JDF Vandersay
# 109626         167      27  KMDN Kulasekara  MJ Henry    JDF Vandersay
# 109627         168      27  KMDN Kulasekara  MJ Henry    JDF Vandersay
#
#         batter_runs  extras_runs  total_delivery_runs wicket_player_out  \
# ...

# %%
df[["batting_team", 'bowling_team','current_runs','current_wickets','overall_ball_n','first_innings_total_runs','preds',"match_id"]][df.overall_ball_n == 75].sample(50)
# Out:
#                 batting_team      bowling_team  current_runs  current_wickets  \
# 88441            New Zealand        Bangladesh            51                3
# 70227            Afghanistan             India            54                1
# 11952               Zimbabwe          Pakistan            32                2
# 76554             Bangladesh      South Africa            28                3
# 65407            West Indies      South Africa            24                3
# 96230              Australia           England            36                5
# 60950              Australia         Sri Lanka            77                0
# 11027               Scotland  Papua New Guinea            48                2
# 80057   United Arab Emirates             India            34                3
# 98809           South Africa          Zimbabwe            60                3
# 47464                  Kenya            Canada            46                4
# ...
